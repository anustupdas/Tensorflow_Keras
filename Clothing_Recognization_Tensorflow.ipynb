# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.12.0

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

print(train_images[0].shape)
# Out:
# (28, 28)

# %%
print(train_labels.shape)
# Out:
# (60000,)

# %%
for i in range (25):
    plt.figure()
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.show()
    print("The train label is: ",train_labels[i])
# Out:
# The train label is:  9
# The train label is:  0
# The train label is:  0
# The train label is:  3
# The train label is:  0
# The train label is:  2
# The train label is:  7
# The train label is:  2
# The train label is:  5
# The train label is:  5
# The train label is:  0
# The train label is:  9
# The train label is:  5
# The train label is:  5
# The train label is:  7
# The train label is:  9
# The train label is:  1
# The train label is:  0
# The train label is:  6
# The train label is:  4
# The train label is:  3
# The train label is:  1
# The train label is:  4
# The train label is:  8
# The train label is:  4

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']


train_images = train_images / 255.0

test_images = test_images / 255.0


count = 0
for i in range (25):
    plt.figure()
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
    plt.show()
    print("The train label is: ",train_labels[i])
# Out:
# The train label is:  9
# The train label is:  0
# The train label is:  0
# The train label is:  3
# The train label is:  0
# The train label is:  2
# The train label is:  7
# The train label is:  2
# The train label is:  5
# The train label is:  5
# The train label is:  0
# The train label is:  9
# The train label is:  5
# The train label is:  5
# The train label is:  7
# The train label is:  9
# The train label is:  1
# The train label is:  0
# The train label is:  6
# The train label is:  4
# The train label is:  3
# The train label is:  1
# The train label is:  4
# The train label is:  8
# The train label is:  4

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

model.compile(optimizer=tf.train.AdamOptimizer(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


model.fit(train_images, train_labels, epochs=5)

test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 69s 1ms/step - loss: 0.4972 - acc: 0.8248
# Epoch 2/5
# 60000/60000 [==============================] - 5s 89us/step - loss: 0.3778 - acc: 0.8625
# Epoch 3/5
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.3372 - acc: 0.8766
# Epoch 4/5
# 60000/60000 [==============================] - 5s 90us/step - loss: 0.3130 - acc: 0.8859
# Epoch 5/5
# ...
# 10000/10000 [==============================] - 14s 1ms/step
# Test accuracy: 0.8761

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 46us/step
# Test accuracy: 0.8761

# %%
predictions = model.predict(test_images)
class_names[np.argmax(predictions[63])]
# Out:
# 'Sandal'

# %%
plt.figure()
plt.imshow(test_images[63], cmap=plt.cm.binary)
plt.xlabel(class_names[test_labels[63]])
plt.show()
print("The train label is: ",test_labels[63])
# Out:
# The train label is:  5
